# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import numpy as np

drop_out_threshold = 1e-5
import random

cnt = Counter()
for int_word in int_words:
    cnt[int_word] += 1
total_count = len(int_words)
train_words = []

for int_word in int_words:
    drop_out_probobality = 1 - np.sqrt(drop_out_threshold/(cnt[int_word]/total_count))
    if not (drop_out_probobality > random.random() and drop_out_probobality > 0):
        train_words.append(int_word)
        
        



# = # The final subsampled word list

print(int_words[0:20])
print(train_words[0:20])

print(len(int_words))
print(len(train_words))
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102]
# [5233, 3133, 155, 476, 10571, 27349, 15067, 58112, 10712, 214, 1324, 362, 686, 7088, 247, 5233, 248, 44611, 186, 200]
# 16680599
# 4628044

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
n_vocab = len(int_to_vocab)
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_embedding = 300# Number of embedding features 
with train_graph.as_default():
    embedding =tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding]))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 21.7129 0.0433 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 21.5275 0.0292 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 21.1513 0.0297 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 21.1595 0.0295 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 20.9291 0.0291 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 20.8023 0.0301 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 20.7389 0.0313 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 20.6309 0.0288 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 20.4437 0.0289 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 20.2697 0.0289 sec/batch
# Nearest to but: paraffin, whistling, tuples, seduce, initiatives, curtailed, bodley, colones,
# Nearest to zero: strangest, interacting, servings, sanchez, highbury, sergeant, elmira, crass,
# Nearest to with: disloyalty, trofim, longmans, ullmann, unsubstantiated, alhazen, moab, canonicity,
# Nearest to that: tau, hessians, gopher, hexagon, mahindra, seamstress, pushkin, shulkhan,
# Nearest to by: ibiza, castaways, ciuszko, portland, mekugi, bord, patrician, regulatory,
# Nearest to may: sds, taxonomists, tann, macfarquhar, aggregation, bassline, republica, morecambe,
# Nearest to or: warners, cantacuzenus, lea, rigdon, militants, divinorum, carelessness, emporium,
# Nearest to first: kurtosis, manutius, weighting, narrating, luminosity, stakeholders, lipsius, akston,
# Nearest to pre: rochdale, sandhi, absolutive, coils, munition, evaporate, cadoc, nymphet,
# Nearest to something: affirms, contractus, complexity, diverted, phased, prosecutions, constrain, berthe,
# Nearest to versions: moonset, kona, disappointed, explainable, regnant, janitor, infix, nnp,
# Nearest to issue: agency, overkill, realities, df, addington, cover, lymphomas, ninhursag,
# Nearest to writers: seam, maybach, fela, paton, mayol, lydian, bearded, charms,
# Nearest to operations: eagle, insufflated, depress, shechem, universitaria, ipsec, manipulation, illustrious,
# Nearest to experience: spotters, distrust, stroud, ke, swept, gunshot, interferon, sugary,
# Nearest to active: monotone, alpes, ifvs, morone, upgrading, ahura, predicting, citeseer,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 20.1826 0.0304 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 19.9966 0.0289 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 19.9049 0.0288 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 19.7508 0.0288 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 19.6949 0.0288 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 19.4939 0.0289 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 19.4039 0.0289 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 19.3397 0.0290 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 19.2891 0.0288 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 19.1214 0.0288 sec/batch
# Nearest to but: paraffin, whistling, tuples, curtailed, initiatives, colones, pictured, jacobitism,
# Nearest to zero: sergeant, strangest, servings, highbury, interacting, shock, ostend, crass,
# Nearest to with: longmans, trofim, disloyalty, alhazen, donato, unsubstantiated, ullmann, reticulum,
# Nearest to that: tau, hessians, gopher, hexagon, mahindra, pectin, seamstress, script,
# Nearest to by: ibiza, castaways, ciuszko, portland, patrician, bord, loemker, gheorghe,
# Nearest to may: sds, taxonomists, macfarquhar, calculates, aeronautics, mj, nucleobases, tann,
# Nearest to or: warners, lea, rigdon, cantacuzenus, militants, divinorum, emporium, conception,
# Nearest to first: kurtosis, manutius, narrating, weighting, fleetwood, stakeholders, synods, intestinal,
# Nearest to pre: rochdale, sandhi, absolutive, nymphet, munition, coils, cadoc, evaporate,
# Nearest to something: affirms, complexity, contractus, phased, diverted, constrain, berthe, banners,
# Nearest to versions: moonset, kona, regnant, explainable, disappointed, janitor, deals, infix,
# Nearest to issue: agency, realities, overkill, df, addington, cover, lymphomas, mechanical,
# Nearest to writers: seam, maybach, scripts, fela, bearded, paton, deadliest, charms,
# Nearest to operations: eagle, insufflated, shechem, depress, universitaria, savanna, peroxide, mobs,
# Nearest to experience: spotters, distrust, stroud, interferon, gunshot, ke, sugary, stagnating,
# Nearest to active: monotone, alpes, ahura, predicting, ifvs, morone, railway, upgrading,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 18.9293 0.0303 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 18.8655 0.0289 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 18.8363 0.0290 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 18.6834 0.0292 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 18.5766 0.0288 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 18.4598 0.0297 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 18.3688 0.0310 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 18.1990 0.0298 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 18.1091 0.0291 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 18.0349 0.0290 sec/batch
# Nearest to but: paraffin, whistling, tuples, curtailed, initiatives, colones, pictured, stupa,
# Nearest to zero: sergeant, strangest, shock, ostend, servings, highbury, elmira, chapters,
# Nearest to with: disloyalty, trofim, longmans, ullmann, donato, alhazen, reticulum, onomatopoeia,
# Nearest to that: hessians, tau, gopher, hexagon, mahindra, seamstress, assisting, cunningham,
# Nearest to by: ibiza, castaways, patrician, ciuszko, loemker, bord, portland, mekugi,
# Nearest to may: sds, taxonomists, mj, nucleobases, calculates, macfarquhar, republica, aggregation,
# Nearest to or: warners, rigdon, lea, divinorum, militants, cantacuzenus, emporium, welding,
# Nearest to first: kurtosis, manutius, weighting, fleetwood, narrating, stakeholders, tatars, luminosity,
# Nearest to pre: rochdale, absolutive, nymphet, cadoc, coils, sandhi, munition, nei,
# Nearest to something: complexity, contractus, affirms, phased, diverted, berthe, inhabits, constrain,
# Nearest to versions: moonset, explainable, kona, infix, regnant, deals, disappointed, janitor,
# Nearest to issue: agency, overkill, realities, cover, df, addington, lymphomas, wesley,
# Nearest to writers: scripts, seam, bearded, maybach, fela, busses, mayol, dt,
# Nearest to operations: eagle, insufflated, depress, shechem, universitaria, savanna, ipsec, illustrious,
# Nearest to experience: spotters, distrust, interferon, stroud, sugary, goodwrench, stagnating, gunshot,
# Nearest to active: monotone, alpes, predicting, ahura, ifvs, lonesome, railway, morone,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 17.9817 0.0307 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 17.8715 0.0289 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 17.7323 0.0293 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 17.5509 0.0292 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 17.5766 0.0293 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 17.4212 0.0291 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 17.3429 0.0291 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 17.3234 0.0291 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 17.1016 0.0288 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 17.1313 0.0289 sec/batch
# Nearest to but: paraffin, tuples, whistling, treasure, curtailed, colones, initiatives, pictured,
# Nearest to zero: sergeant, highbury, strangest, ostend, servings, elmira, shock, procter,
# Nearest to with: disloyalty, trofim, longmans, donato, trebia, canonicity, ullmann, onomatopoeia,
# Nearest to that: gopher, tau, hessians, hexagon, assisting, mahindra, implementation, professionals,
# Nearest to by: ibiza, castaways, loemker, patrician, ciuszko, bord, portland, underlie,
# Nearest to may: sds, taxonomists, nucleobases, aggregation, mj, macfarquhar, republica, escorts,
# Nearest to or: warners, rigdon, lea, militants, divinorum, emporium, cantacuzenus, submachine,
# Nearest to first: kurtosis, manutius, fleetwood, weighting, narrating, stakeholders, tatars, dt,
# Nearest to pre: absolutive, rochdale, sandhi, nymphet, munition, coils, cadoc, nei,
# Nearest to something: complexity, contractus, affirms, diverted, phased, berthe, constrain, yakovlev,
# Nearest to versions: moonset, explainable, kona, infix, regnant, deals, janitor, nnp,
# Nearest to issue: agency, overkill, realities, cover, addington, lymphomas, df, wesley,
# Nearest to writers: scripts, seam, maybach, bearded, busses, fela, gurkha, paton,
# Nearest to operations: eagle, insufflated, depress, savanna, universitaria, shechem, peroxide, walid,
# Nearest to experience: interferon, distrust, spotters, sugary, stroud, goodwrench, australopithecines, ke,
# Nearest to active: monotone, alpes, ahura, predicting, railway, lonesome, upgrading, morone,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 16.9837 0.0302 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 16.9217 0.0290 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 16.6437 0.0290 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 16.6141 0.0289 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 16.6869 0.0289 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 16.5552 0.0288 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 16.3809 0.0210 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 16.2294 0.0294 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 16.0908 0.0334 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 15.9522 0.0292 sec/batch
# Nearest to but: paraffin, tuples, pictured, curtailed, whistling, treasure, gold, initiatives,
# Nearest to zero: highbury, exabyte, sergeant, predictability, procter, clubbing, ooze, ayy,
# Nearest to with: disloyalty, trofim, trebia, longmans, canonicity, castlevania, donato, streptococci,
# Nearest to that: gopher, tau, cunningham, hexagon, greater, hessians, monotheism, staking,
# Nearest to by: ibiza, castaways, loemker, patrician, bord, underlie, ciuszko, pickover,
# Nearest to may: sds, taxonomists, aggregation, nucleobases, calculates, macfarquhar, tann, aeronautics,
# Nearest to or: warners, rigdon, lea, militants, divinorum, conception, cantacuzenus, warm,
# Nearest to first: kurtosis, fleetwood, narrating, weighting, tatars, stakeholders, manutius, miriam,
# Nearest to pre: absolutive, nei, nymphet, rochdale, coils, capitan, munition, cadoc,
# Nearest to something: contractus, constrain, complexity, affirms, yakovlev, phased, diverted, berthe,
# Nearest to versions: moonset, explainable, kona, janitor, infix, deals, pooh, regnant,
# Nearest to issue: agency, overkill, realities, df, lymphomas, addington, cover, mechanical,
# Nearest to writers: scripts, bearded, seam, maybach, deadliest, busses, paton, gurkha,
# Nearest to operations: eagle, insufflated, universitaria, depress, savanna, peroxide, technicians, shechem,
# Nearest to experience: interferon, distrust, spotters, sugary, stroud, goodwrench, ke, stagnating,
# Nearest to active: monotone, alpes, ahura, predicting, upgrading, citeseer, lonesome, stationing,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 15.8888 0.0306 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 15.7440 0.0292 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 15.7282 0.0298 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 15.7007 0.0296 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 15.5808 0.0298 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 15.5267 0.0293 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 15.3878 0.0289 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 15.1865 0.0290 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 15.1362 0.0292 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 15.1913 0.0290 sec/batch
# Nearest to but: paraffin, pictured, whistling, tuples, curtailed, gold, initiatives, conserving,
# Nearest to zero: in, the, one, highbury, seven, sanchez, elmira, to,
# Nearest to with: trebia, trofim, disloyalty, from, the, ramanuja, meadows, mariani,
# Nearest to that: the, greater, staking, gopher, cunningham, hexagon, decorate, epitome,
# Nearest to by: ibiza, the, in, pickover, bord, castaways, a, mane,
# Nearest to may: sds, nucleobases, macfarquhar, calculates, aggregation, aeronautics, tann, escorts,
# Nearest to or: warners, welding, lea, goldman, the, rigdon, warm, cantacuzenus,
# Nearest to first: kurtosis, fleetwood, weighting, dt, tatars, dunn, narrating, cleese,
# Nearest to pre: absolutive, nymphet, nei, coils, munition, cadoc, rochdale, capitan,
# Nearest to something: complexity, contractus, constrain, affirms, diverted, inhabits, motility, phased,
# Nearest to versions: moonset, kona, explainable, janitor, deals, regnant, ephemerides, infix,
# Nearest to issue: agency, overkill, realities, df, cover, lymphomas, mechanical, addington,
# Nearest to writers: scripts, bearded, busses, maybach, seam, eradicating, dt, paton,
# Nearest to operations: eagle, insufflated, depress, universitaria, peroxide, shechem, savanna, walid,
# Nearest to experience: interferon, distrust, stroud, stagnating, goodwrench, sugary, spotters, truce,
# Nearest to active: monotone, alpes, ahura, citeseer, upgrading, predicting, stationing, lonesome,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 15.1034 0.0308 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 14.9406 0.0292 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 14.8710 0.0292 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 14.7824 0.0294 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 14.7898 0.0290 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 14.7143 0.0290 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 14.4394 0.0290 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 14.5265 0.0291 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 14.4440 0.0290 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 14.2726 0.0292 sec/batch
# Nearest to but: in, the, of, and, paraffin, whistling, gold, pictured,
# Nearest to zero: the, one, of, to, in, and, three, a,
# Nearest to with: the, of, a, to, in, and, is, from,
# Nearest to that: a, as, the, in, to, and, of, is,
# Nearest to by: the, a, of, in, and, as, to, one,
# Nearest to may: sds, nucleobases, escorts, oper, macfarquhar, aggregation, calculates, wedding,
# Nearest to or: is, of, as, and, the, to, one, an,
# Nearest to first: kurtosis, dt, mago, tatars, fleetwood, narrating, miriam, dunn,
# Nearest to pre: absolutive, nei, nymphet, coils, munition, capitan, cadoc, rochdale,
# Nearest to something: contractus, berthe, complexity, constrain, inhabits, affirms, phased, prosecutions,
# Nearest to versions: moonset, janitor, explainable, kona, deals, regnant, xof, infix,
# Nearest to issue: agency, overkill, realities, cover, lymphomas, df, addington, mechanical,
# Nearest to writers: scripts, seam, maybach, busses, following, bearded, deadliest, fela,
# Nearest to operations: eagle, universitaria, insufflated, depress, peroxide, technicians, savanna, manipulation,
# Nearest to experience: interferon, distrust, stroud, swept, page, goodwrench, sugary, spotters,
# Nearest to active: ahura, monotone, alpes, upgrading, citeseer, predicting, lonesome, coolidge,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 14.4927 0.0304 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 14.2299 0.0290 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 13.9738 0.0292 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 14.1234 0.0292 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 14.0498 0.0293 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 13.8417 0.0290 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 13.8663 0.0292 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 13.8636 0.0292 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 13.5706 0.0291 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 13.5512 0.0284 sec/batch
# Nearest to but: to, is, a, the, of, was, as, that,
# Nearest to zero: one, two, nine, the, three, and, in, of,
# Nearest to with: to, the, and, in, a, of, for, as,
# Nearest to that: the, to, of, is, and, as, a, in,
# Nearest to by: a, to, the, of, in, and, is, as,
# Nearest to may: sds, as, on, wedding, to, which, their, escorts,
# Nearest to or: to, is, of, the, and, as, in, that,
# Nearest to first: s, three, nine, eight, two, but, and, to,
# Nearest to pre: absolutive, nei, coils, nymphet, cadoc, capitan, munition, ftl,
# Nearest to something: contractus, constrain, inhabits, berthe, selwyn, complexity, affirms, prosecutions,
# Nearest to versions: moonset, janitor, kona, regnant, explainable, infix, deals, disappointed,
# Nearest to issue: agency, overkill, df, cover, lymphomas, realities, addington, dubai,
# Nearest to writers: scripts, following, eradicating, busses, seam, lydian, deadliest, maybach,
# Nearest to operations: eagle, universitaria, insufflated, depress, sail, peroxide, alameda, savanna,
# Nearest to experience: distrust, interferon, stroud, stagnating, sugary, ke, page, swept,
# Nearest to active: ahura, monotone, alpes, upgrading, citeseer, predicting, lonesome, stationing,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 13.5353 0.0299 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 13.6677 0.0286 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 13.5401 0.0286 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 13.3638 0.0286 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 13.3069 0.0285 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 13.1244 0.0285 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 13.2617 0.0284 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 13.1559 0.0283 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 12.9308 0.0285 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 12.9859 0.0285 sec/batch
# Nearest to but: the, to, that, in, it, of, not, and,
# Nearest to zero: two, three, one, five, six, four, nine, eight,
# Nearest to with: of, the, in, a, to, from, and, was,
# Nearest to that: the, to, a, of, as, and, is, in,
# Nearest to by: of, a, the, in, and, to, is, that,
# Nearest to may: the, their, which, of, from, in, by, that,
# Nearest to or: to, it, that, by, as, this, is, a,
# Nearest to first: two, four, the, for, in, was, and, eight,
# Nearest to pre: absolutive, nei, ftl, capitan, coils, munition, retouched, existence,
# Nearest to something: contractus, inhabits, constrain, complexity, selwyn, prosecutions, berthe, tawi,
# Nearest to versions: moonset, janitor, kona, infix, deals, dictionary, history, regnant,
# Nearest to issue: overkill, agency, cover, lymphomas, df, addington, mechanical, realities,
# Nearest to writers: scripts, following, eradicating, seam, deadliest, bizkit, busses, dt,
# Nearest to operations: eagle, insufflated, universitaria, depress, sail, distinctions, alameda, slavonic,
# Nearest to experience: interferon, distrust, stroud, ke, swept, australopithecines, bs, sugary,
# Nearest to active: monotone, ahura, upgrading, alpes, citeseer, predicting, reelected, railway,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 12.9535 0.0305 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 12.8728 0.0290 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 12.7512 0.0130 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 12.5845 0.0289 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 12.6597 0.0289 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 12.4946 0.0290 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 12.4665 0.0289 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 12.4501 0.0289 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 12.1902 0.0289 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 12.1379 0.0293 sec/batch
# Nearest to but: the, by, and, was, have, to, that, as,
# Nearest to zero: two, one, five, four, three, nine, eight, six,
# Nearest to with: the, of, to, in, as, by, and, which,
# Nearest to that: to, of, in, are, the, have, or, a,
# Nearest to by: the, in, of, to, a, and, was, with,
# Nearest to may: of, to, be, an, not, their, in, the,
# Nearest to or: a, are, that, to, is, and, for, the,
# Nearest to first: and, the, of, in, was, six, two, one,
# Nearest to pre: absolutive, munition, nei, capitan, ftl, retouched, coils, biker,
# Nearest to something: contractus, complexity, inhabits, selwyn, berthe, prosecutions, constrain, affirms,
# Nearest to versions: moonset, they, it, kona, janitor, history, infix, dictionary,
# Nearest to issue: overkill, agency, cover, addington, lymphomas, dubai, lifeforms, df,
# Nearest to writers: following, scripts, eradicating, paton, deadliest, bizkit, point, seam,
# Nearest to operations: eagle, insufflated, universitaria, alameda, sail, slavonic, distinctions, peroxide,
# Nearest to experience: interferon, distrust, stroud, swept, australopithecines, china, sugary, bs,
# Nearest to active: alpes, monotone, ahura, upgrading, predicting, citeseer, vallarta, lesion,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 12.1753 0.0305 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 12.1363 0.0290 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 11.9652 0.0289 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 11.6448 0.0290 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 11.8305 0.0289 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 11.7990 0.0289 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 12.0028 0.0291 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 11.8045 0.0291 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 11.6014 0.0290 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 11.6060 0.0289 sec/batch
# Nearest to but: the, of, to, a, in, that, this, be,
# Nearest to zero: two, one, three, five, eight, six, four, seven,
# Nearest to with: the, it, for, of, to, was, in, and,
# Nearest to that: the, of, is, a, it, to, this, be,
# Nearest to by: the, and, of, an, to, in, a, it,
# Nearest to may: of, a, an, to, the, as, it, have,
# Nearest to or: the, and, to, of, this, it, a, are,
# Nearest to first: the, and, was, in, a, of, to, s,
# Nearest to pre: nei, absolutive, capitan, existence, biker, munition, cadoc, nymphet,
# Nearest to something: contractus, berthe, inhabits, constrain, selwyn, complexity, recovers, disgust,
# Nearest to versions: moonset, not, kona, then, janitor, dictionary, own, history,
# Nearest to issue: overkill, agency, cover, lifeforms, dubai, lymphomas, addington, mechanical,
# Nearest to writers: scripts, eradicating, following, meretzky, paton, fianc, bizkit, practices,
# Nearest to operations: eagle, manipulation, insufflated, alameda, sail, peroxide, slavonic, make,
# Nearest to experience: interferon, distrust, china, more, swept, stroud, quimby, countries,
# Nearest to active: alpes, ahura, predicting, monotone, lesion, citeseer, vallarta, hoarding,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 11.6254 0.0303 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 11.6636 0.0289 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 11.1729 0.0290 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 11.4024 0.0288 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 11.3933 0.0289 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 11.2479 0.0289 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 11.2765 0.0290 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 11.3981 0.0288 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 10.8572 0.0290 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 11.0540 0.0290 sec/batch
# Nearest to but: to, the, of, and, in, for, it, as,
# Nearest to zero: three, two, one, four, six, nine, five, eight,
# Nearest to with: the, to, as, in, a, by, of, for,
# Nearest to that: to, the, of, it, is, for, be, are,
# Nearest to by: the, of, to, in, is, a, for, as,
# Nearest to may: to, is, be, the, for, or, of, are,
# Nearest to or: is, the, to, are, be, in, a, of,
# Nearest to first: of, in, was, s, the, on, by, and,
# Nearest to pre: absolutive, capitan, nei, biker, status, overwhelmingly, existence, coils,
# Nearest to something: contractus, cases, berthe, selwyn, complexity, inhabits, constrain, approach,
# Nearest to versions: moonset, later, based, be, by, own, kona, can,
# Nearest to issue: overkill, north, agency, cover, with, lifeforms, october, mechanical,
# Nearest to writers: scripts, following, fianc, eradicating, rhymed, tackled, meretzky, harnesses,
# Nearest to operations: make, eagle, described, alameda, sail, manipulation, insufflated, precipitation,
# Nearest to experience: interferon, another, about, distrust, more, countries, china, likely,
# Nearest to active: alpes, ahura, predicting, lesion, klement, ryle, upgrading, hoarding,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 11.1654 0.0301 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 10.8528 0.0290 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 10.9062 0.0288 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 10.8442 0.0289 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 10.7532 0.0290 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 10.6670 0.0289 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 10.6176 0.0289 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 10.7467 0.0296 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 10.6382 0.0295 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 10.5619 0.0296 sec/batch
# Nearest to but: a, the, of, as, to, for, that, an,
# Nearest to zero: five, two, three, four, eight, one, seven, nine,
# Nearest to with: the, of, in, and, to, a, as, from,
# Nearest to that: to, the, a, it, and, is, of, as,
# Nearest to by: the, of, and, to, for, in, it, a,
# Nearest to may: not, for, it, however, the, is, or, of,
# Nearest to or: not, a, to, be, are, it, is, for,
# Nearest to first: the, in, and, a, at, he, s, to,
# Nearest to pre: capitan, existence, period, biker, status, coils, absolutive, ftl,
# Nearest to something: cases, almost, very, that, any, likely, contractus, single,
# Nearest to versions: popular, will, which, fact, life, to, thus, so,
# Nearest to issue: north, taken, due, if, generally, where, do, although,
# Nearest to writers: scripts, fianc, called, name, th, eradicating, practices, links,
# Nearest to operations: sail, eagle, alameda, manipulation, described, insufflated, use, make,
# Nearest to experience: i, over, rather, any, people, likely, for, china,
# Nearest to active: alpes, ahura, certain, lesion, klement, reelected, predicting, upgrading,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 10.7914 0.0309 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 10.1395 0.0291 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 10.5335 0.0289 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 10.4773 0.0292 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 10.0886 0.0292 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 10.3221 0.0293 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 10.2508 0.0293 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 10.2274 0.0292 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 10.2380 0.0050 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 10.0215 0.0291 sec/batch
# Nearest to but: that, a, the, as, to, not, have, in,
# Nearest to zero: two, four, five, three, six, one, eight, seven,
# Nearest to with: in, the, to, of, a, and, by, for,
# Nearest to that: to, the, not, a, of, in, have, or,
# Nearest to by: in, and, the, of, to, a, as, for,
# Nearest to may: the, or, of, to, as, in, that, a,
# Nearest to or: is, that, a, the, to, it, may, are,
# Nearest to first: in, by, the, to, and, of, a, with,
# Nearest to pre: the, over, history, site, long, most, existence, several,
# Nearest to something: cases, that, can, not, we, their, will, very,
# Nearest to versions: will, can, original, these, used, case, each, not,
# Nearest to issue: taken, very, generally, m, north, all, as, next,
# Nearest to writers: scripts, seen, though, special, thought, there, practices, century,
# Nearest to operations: sail, another, described, there, eagle, which, insufflated, been,
# Nearest to experience: i, came, popular, third, likely, according, not, countries,
# Nearest to active: certain, practice, to, all, started, first, must, that,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 10.0472 0.0307 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 10.1551 0.0296 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 9.8495 0.0294 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 10.0430 0.0291 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 9.7584 0.0290 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 9.6192 0.0289 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 9.6944 0.0289 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 9.7050 0.0289 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 9.6478 0.0289 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 9.2543 0.0290 sec/batch
# Nearest to but: the, in, to, and, by, of, a, from,
# Nearest to zero: two, four, three, five, seven, eight, one, six,
# Nearest to with: the, a, in, of, to, and, from, are,
# Nearest to that: the, a, is, to, not, are, from, or,
# Nearest to by: the, from, in, of, and, a, only, as,
# Nearest to may: not, is, that, the, to, and, or, in,
# Nearest to or: be, is, that, which, the, to, from, of,
# Nearest to first: the, in, and, by, to, a, of, was,
# Nearest to pre: similar, was, western, due, other, with, modern, throughout,
# Nearest to something: that, we, not, very, does, an, can, may,
# Nearest to versions: they, based, original, being, it, a, be, used,
# Nearest to issue: still, power, means, this, due, more, on, political,
# Nearest to writers: seen, name, there, the, western, work, england, of,
# Nearest to operations: however, such, another, provide, due, into, often, has,
# Nearest to experience: way, their, is, may, not, another, if, though,
# Nearest to active: practice, up, in, certain, to, various, which, will,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 9.4426 0.0303 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 9.3632 0.0289 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 9.5734 0.0288 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 9.5351 0.0288 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 9.2379 0.0289 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 9.3680 0.0289 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 9.3641 0.0288 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 9.4210 0.0290 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 8.9328 0.0289 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 9.1077 0.0288 sec/batch
# Nearest to but: the, to, of, that, from, in, it, as,
# Nearest to zero: two, four, five, one, three, nine, six, seven,
# Nearest to with: to, the, and, a, in, on, as, of,
# Nearest to that: to, is, it, the, this, be, as, a,
# Nearest to by: of, the, in, for, to, and, is, as,
# Nearest to may: to, that, or, it, be, the, is, a,
# Nearest to or: it, a, is, this, as, to, are, an,
# Nearest to first: was, the, s, to, of, and, in, by,
# Nearest to pre: made, since, was, and, even, the, city, including,
# Nearest to something: not, that, an, this, example, any, but, it,
# Nearest to versions: original, when, each, they, will, number, way, this,
# Nearest to issue: with, to, due, the, as, most, be, within,
# Nearest to writers: england, great, john, early, events, history, in, general,
# Nearest to operations: such, number, range, different, has, system, due, including,
# Nearest to experience: whether, likely, that, it, different, would, do, about,
# Nearest to active: other, a, certain, all, and, they, that, with,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 9.1669 0.0302 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 9.0358 0.0289 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 9.0395 0.0290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 9.1923 0.0288 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 8.8681 0.0289 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 8.8076 0.0289 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 9.0607 0.0288 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 8.7746 0.0289 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 8.8102 0.0289 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 8.8131 0.0289 sec/batch
# Nearest to but: to, in, the, of, and, by, that, a,
# Nearest to zero: one, two, three, five, four, six, nine, seven,
# Nearest to with: in, a, to, the, and, of, on, has,
# Nearest to that: be, is, not, a, to, this, it, in,
# Nearest to by: the, of, in, and, a, to, on, as,
# Nearest to may: are, or, is, that, to, the, be, a,
# Nearest to or: is, not, be, a, are, to, this, often,
# Nearest to first: in, of, the, and, a, on, to, was,
# Nearest to pre: the, found, of, were, been, was, from, since,
# Nearest to something: that, be, not, is, or, this, do, but,
# Nearest to versions: version, available, is, standard, can, it, to, original,
# Nearest to issue: another, to, this, the, which, of, a, in,
# Nearest to writers: events, old, named, history, view, great, notable, english,
# Nearest to operations: since, addition, long, significant, which, by, such, on,
# Nearest to experience: likely, own, not, should, it, whether, different, already,
# Nearest to active: a, that, they, to, various, so, have, of,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 8.9146 0.0303 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 8.4859 0.0288 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 8.5372 0.0289 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 8.7909 0.0290 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 8.6744 0.0290 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 8.5997 0.0289 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 8.8485 0.0289 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 8.3181 0.0290 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 8.5853 0.0290 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 8.6997 0.0287 sec/batch
# Nearest to but: to, the, a, that, is, they, be, by,
# Nearest to zero: two, three, five, four, seven, one, six, nine,
# Nearest to with: the, in, and, to, an, from, as, of,
# Nearest to that: to, all, is, the, have, not, as, it,
# Nearest to by: the, to, and, of, a, on, s, in,
# Nearest to may: however, be, the, is, that, as, a, have,
# Nearest to or: be, this, is, it, that, are, have, a,
# Nearest to first: was, at, in, for, the, to, did, one,
# Nearest to pre: the, most, other, and, that, of, has, as,
# Nearest to something: not, that, you, have, what, be, way, is,
# Nearest to versions: version, use, each, can, for, based, system, free,
# Nearest to issue: the, this, been, to, however, with, by, there,
# Nearest to writers: th, science, wrote, short, english, according, society, christian,
# Nearest to operations: that, use, another, will, much, which, number, information,
# Nearest to experience: likely, be, that, as, not, our, on, if,
# Nearest to active: have, into, are, the, and, that, they, while,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 8.3368 0.0302 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 8.3892 0.0290 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 8.3404 0.0289 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 8.4606 0.0289 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 8.4717 0.0290 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 8.1737 0.0256 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 8.3347 0.0289 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 8.3896 0.0290 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 8.1885 0.0292 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 8.2818 0.0289 sec/batch
# Nearest to but: the, a, that, and, to, their, by, of,
# Nearest to zero: four, two, three, five, eight, six, one, nine,
# Nearest to with: the, to, and, a, in, of, for, by,
# Nearest to that: to, the, be, and, or, there, have, as,
# Nearest to by: the, of, in, and, which, to, on, a,
# Nearest to may: which, to, the, is, be, or, a, that,
# Nearest to or: is, be, are, a, that, have, to, there,
# Nearest to first: and, in, of, the, had, by, to, s,
# Nearest to pre: from, and, of, the, on, with, most, in,
# Nearest to something: be, that, not, will, to, does, must, any,
# Nearest to versions: version, systems, for, available, system, based, designed, released,
# Nearest to issue: as, the, to, by, a, and, in, of,
# Nearest to writers: who, his, wrote, of, science, links, book, society,
# Nearest to operations: an, system, use, which, using, these, each, possible,
# Nearest to experience: not, that, human, however, itself, how, whether, ability,
# Nearest to active: and, the, within, to, that, in, they, them,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 8.1599 0.0301 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.9289 0.0288 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 8.0549 0.0288 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 8.0220 0.0289 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 8.0358 0.0289 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.7166 0.0289 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 7.6921 0.0289 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.8288 0.0289 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.8949 0.0288 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.9867 0.0288 sec/batch
# Nearest to but: a, to, the, of, their, have, and, no,
# Nearest to zero: two, five, one, six, four, three, eight, seven,
# Nearest to with: and, the, to, a, of, which, has, there,
# Nearest to that: the, to, it, a, have, not, is, be,
# Nearest to by: the, and, a, to, in, of, which, on,
# Nearest to may: it, be, is, all, or, to, these, that,
# Nearest to or: are, to, the, this, is, be, some, of,
# Nearest to first: was, and, the, in, s, one, on, a,
# Nearest to pre: of, and, were, was, the, many, has, a,
# Nearest to something: it, not, a, to, that, might, same, be,
# Nearest to versions: version, based, available, computer, systems, release, information, performance,
# Nearest to issue: the, of, to, by, and, many, in, such,
# Nearest to writers: wrote, science, writing, who, death, old, great, works,
# Nearest to operations: to, these, system, are, number, any, of, need,
# Nearest to experience: that, do, even, not, to, the, would, a,
# Nearest to active: the, and, to, with, on, in, various, of,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 7.7621 0.0302 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.7628 0.0288 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.7623 0.0289 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.9019 0.0289 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.6767 0.0289 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 7.4577 0.0288 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 7.6588 0.0289 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 7.7217 0.0288 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 7.5225 0.0289 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.7744 0.0289 sec/batch
# Nearest to but: for, the, in, to, this, with, by, a,
# Nearest to zero: two, three, one, five, four, six, nine, eight,
# Nearest to with: a, to, as, the, for, in, that, of,
# Nearest to that: it, is, a, to, not, this, or, as,
# Nearest to by: the, of, in, a, to, for, on, with,
# Nearest to may: is, a, by, for, that, with, it, to,
# Nearest to or: is, it, that, are, because, with, usually, be,
# Nearest to first: was, s, in, the, of, and, on, by,
# Nearest to pre: the, most, in, of, and, been, several, were,
# Nearest to something: that, not, it, they, even, be, or, this,
# Nearest to versions: available, version, based, it, programs, read, computer, using,
# Nearest to issue: the, in, to, however, of, s, on, by,
# Nearest to writers: works, who, was, science, century, after, books, great,
# Nearest to operations: with, using, program, number, is, an, which, to,
# Nearest to experience: be, an, it, do, to, or, not, this,
# Nearest to active: the, with, by, a, of, that, for, and,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 7.4976 0.0301 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 7.3480 0.0288 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 7.6242 0.0289 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 7.5454 0.0290 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 7.4288 0.0289 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 7.4278 0.0290 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 7.5688 0.0288 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 7.1376 0.0289 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 7.3335 0.0288 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 7.2571 0.0290 sec/batch
# Nearest to but: a, as, the, of, to, on, it, with,
# Nearest to zero: two, three, five, four, six, one, seven, nine,
# Nearest to with: the, and, a, to, as, of, by, in,
# Nearest to that: a, as, is, of, to, the, not, it,
# Nearest to by: the, and, of, to, in, it, a, with,
# Nearest to may: it, are, is, not, or, be, any, thus,
# Nearest to or: are, not, is, be, a, some, usually, used,
# Nearest to first: s, the, and, in, of, new, a, at,
# Nearest to pre: in, the, and, of, from, by, has, s,
# Nearest to something: so, not, it, be, they, might, do, should,
# Nearest to versions: version, computer, programs, additional, feature, system, available, operating,
# Nearest to issue: to, of, and, the, its, for, in, from,
# Nearest to writers: science, literature, contemporary, influential, english, history, famous, book,
# Nearest to operations: which, for, a, that, to, number, an, as,
# Nearest to experience: a, not, an, be, might, that, itself, them,
# Nearest to active: and, a, the, to, not, of, which, with,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 7.4769 0.0302 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 7.4255 0.0289 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 7.4968 0.0289 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 7.3731 0.0288 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 7.1430 0.0289 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 7.4866 0.0287 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 7.2522 0.0296 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 7.0844 0.0293 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 7.1929 0.0289 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 7.3308 0.0289 sec/batch
# Nearest to but: to, the, it, a, that, has, as, in,
# Nearest to zero: two, three, four, five, one, six, nine, eight,
# Nearest to with: the, to, a, as, in, on, by, and,
# Nearest to that: a, to, the, not, it, as, have, be,
# Nearest to by: the, of, in, a, and, to, as, on,
# Nearest to may: not, a, this, that, to, the, these, as,
# Nearest to or: is, a, be, are, it, used, have, as,
# Nearest to first: s, the, new, in, and, to, after, of,
# Nearest to pre: of, most, though, the, in, it, other, today,
# Nearest to something: not, must, think, might, be, that, anything, what,
# Nearest to versions: version, system, based, operating, systems, application, computer, release,
# Nearest to issue: to, the, of, been, within, from, in, however,
# Nearest to writers: influential, book, history, authors, literature, story, famous, works,
# Nearest to operations: a, for, use, is, the, operation, small, it,
# Nearest to experience: do, be, that, knowledge, our, these, to, such,
# Nearest to active: to, the, with, in, a, of, an, as,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 7.2763 0.0303 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 7.1773 0.0177 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 7.1477 0.0290 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 7.1508 0.0289 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 7.0590 0.0290 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 7.0835 0.0290 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 7.1222 0.0289 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.9769 0.0288 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.8415 0.0289 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.9739 0.0290 sec/batch
# Nearest to but: to, it, a, with, other, have, this, that,
# Nearest to zero: two, three, five, eight, four, one, seven, nine,
# Nearest to with: the, of, and, a, in, to, by, which,
# Nearest to that: is, not, have, as, or, an, be, of,
# Nearest to by: the, of, in, to, and, a, as, from,
# Nearest to may: is, as, other, have, it, be, or, these,
# Nearest to or: is, be, have, that, more, are, such, which,
# Nearest to first: the, was, in, at, and, to, had, of,
# Nearest to pre: as, the, of, in, to, been, and, by,
# Nearest to something: be, might, must, that, not, does, no, any,
# Nearest to versions: version, computer, operating, systems, application, standard, software, system,
# Nearest to issue: to, of, by, not, in, their, all, been,
# Nearest to writers: works, wrote, authors, story, biography, literature, history, published,
# Nearest to operations: set, each, if, using, more, operation, is, number,
# Nearest to experience: be, not, may, how, that, these, individual, own,
# Nearest to active: in, and, has, as, into, from, a, important,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 7.0082 0.0304 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.7477 0.0290 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.6302 0.0290 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.7637 0.0290 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.8452 0.0289 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 7.0463 0.0288 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.8559 0.0289 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.7363 0.0290 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.6478 0.0289 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.8822 0.0288 sec/batch
# Nearest to but: to, the, of, that, they, have, as, and,
# Nearest to zero: two, five, four, three, one, six, seven, eight,
# Nearest to with: and, the, to, a, of, in, on, as,
# Nearest to that: to, this, be, of, have, the, for, not,
# Nearest to by: the, of, and, in, to, on, as, a,
# Nearest to may: this, that, or, it, as, for, to, a,
# Nearest to or: is, a, are, any, be, it, because, such,
# Nearest to first: s, was, and, the, in, by, last, on,
# Nearest to pre: in, the, of, many, were, a, with, and,
# Nearest to something: not, way, an, could, often, so, might, it,
# Nearest to versions: version, operating, screen, computer, video, performance, systems, programs,
# Nearest to issue: by, to, in, of, the, view, people, decision,
# Nearest to writers: fiction, influenced, literary, science, works, authors, wrote, stories,
# Nearest to operations: need, for, system, set, operation, number, provides, which,
# Nearest to experience: that, not, it, have, to, do, human, will,
# Nearest to active: of, and, in, on, which, the, to, as,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 6.8866 0.0301 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 6.4853 0.0289 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 6.6959 0.0288 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 6.7549 0.0288 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 6.5479 0.0289 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 6.8079 0.0289 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 6.7141 0.0289 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 6.3961 0.0289 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 6.6884 0.0288 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 6.7032 0.0289 sec/batch
# ...
# Nearest to with: the, to, and, a, in, on, by, but,
# Nearest to that: not, be, it, does, this, have, no, so,
# Nearest to by: of, the, in, and, from, as, s, to,
# Nearest to may: that, these, does, or, have, such, be, is,
# Nearest to or: is, have, some, be, these, other, which, either,
# Nearest to first: on, was, s, fourth, started, later, a, new,
# Nearest to pre: of, the, many, as, european, in, most, century,
# Nearest to something: anything, say, does, things, that, know, might, we,
# Nearest to versions: version, operating, computer, software, screen, computers, release, video,
# Nearest to issue: decision, rights, issues, deal, policy, independent, political, interests,
# Nearest to writers: literature, literary, poets, biography, author, fiction, authors, stories,
# Nearest to operations: operation, program, support, operational, operators, require, technical, improved,
# Nearest to experience: feeling, perception, that, our, does, whether, how, understand,
# Nearest to active: primary, specific, depending, level, such, large, due, process,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 5.1723 0.0300 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 5.1117 0.0289 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 5.2068 0.0295 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 5.2353 0.0290 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.3256 0.0289 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 5.2015 0.0289 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.2289 0.0288 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 5.1954 0.0290 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.3235 0.0289 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.3065 0.0290 sec/batch
# Nearest to but: to, the, that, not, it, as, more, another,
# Nearest to zero: two, five, four, six, three, nine, one, seven,
# Nearest to with: the, a, to, and, in, on, of, an,
# Nearest to that: be, not, is, to, it, this, but, the,
# Nearest to by: the, and, of, in, a, with, for, an,
# Nearest to may: not, be, or, to, does, that, it, some,
# Nearest to or: are, is, be, some, such, as, it, a,
# Nearest to first: was, s, on, the, at, in, later, and,
# Nearest to pre: the, of, in, today, european, which, abandoned, during,
# Nearest to something: know, not, thing, anything, say, tell, you, want,
# Nearest to versions: version, video, released, release, pc, introduced, releases, screen,
# Nearest to issue: issues, been, decision, not, to, has, of, view,
# Nearest to writers: literary, fiction, literature, authors, works, science, biography, essay,
# Nearest to operations: operation, support, operates, system, program, operate, implement, implementing,
# Nearest to experience: not, that, does, do, be, person, human, whether,
# Nearest to active: large, due, especially, small, include, increasing, local, in,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 5.1185 0.0301 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 5.2026 0.0289 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.2294 0.0289 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 5.1462 0.0289 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.2888 0.0288 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 5.1728 0.0290 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 5.0237 0.0290 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.2148 0.0289 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 5.1936 0.0289 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 5.1405 0.0289 sec/batch
# Nearest to but: to, as, however, a, their, in, the, with,
# Nearest to zero: two, three, four, five, one, nine, seven, six,
# Nearest to with: a, in, the, and, to, by, as, this,
# Nearest to that: be, not, any, might, this, is, an, to,
# Nearest to by: the, of, and, a, to, from, in, an,
# Nearest to may: or, be, these, have, are, some, because, that,
# Nearest to or: are, used, may, be, is, have, different, these,
# Nearest to first: was, at, on, new, during, s, from, by,
# Nearest to pre: in, the, of, been, and, several, today, from,
# Nearest to something: what, might, know, say, person, think, things, really,
# Nearest to versions: version, newer, computer, editors, text, format, images, using,
# Nearest to issue: to, an, not, that, opinion, those, debate, what,
# Nearest to writers: fiction, author, authors, literature, literary, biography, novel, science,
# Nearest to operations: operation, armed, program, combat, u, joint, division, forces,
# Nearest to experience: what, that, thinking, not, perceive, perception, cannot, know,
# Nearest to active: from, most, internal, of, provides, to, include, activity,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 5.1714 0.0301 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 5.1982 0.0289 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 5.0264 0.0289 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 5.0499 0.0287 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 5.1162 0.0290 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 5.1459 0.0291 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 5.2222 0.0288 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.2973 0.0290 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.2955 0.0289 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 5.0254 0.0288 sec/batch
# Nearest to but: to, that, a, the, however, it, not, their,
# Nearest to zero: two, four, three, five, seven, one, six, eight,
# Nearest to with: the, by, and, to, from, in, of, it,
# Nearest to that: not, have, but, a, so, the, be, this,
# Nearest to by: the, of, and, to, in, with, as, a,
# Nearest to may: have, as, that, to, not, or, however, is,
# Nearest to or: some, different, such, often, are, sometimes, is, used,
# Nearest to first: after, was, new, s, in, at, became, the,
# Nearest to pre: from, of, the, more, other, also, there, while,
# Nearest to something: what, know, really, so, how, wrong, does, think,
# Nearest to versions: version, windows, operating, graphics, newer, available, computer, text,
# Nearest to issue: political, opinion, legal, that, rights, not, to, matters,
# Nearest to writers: fiction, science, literary, authors, novelists, biographical, literature, poets,
# Nearest to operations: operation, u, armed, force, joint, operates, equipped, division,
# Nearest to experience: how, experiences, thinking, feeling, something, our, do, know,
# Nearest to active: and, ongoing, of, most, their, from, member, community,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 5.1840 0.0300 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 5.1380 0.0287 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 5.0008 0.0289 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 5.0533 0.0290 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 5.1568 0.0290 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 5.1006 0.0289 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 5.1726 0.0141 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 5.0504 0.0289 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 5.1253 0.0290 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 5.0990 0.0289 sec/batch
# Nearest to but: a, the, it, were, to, however, that, not,
# Nearest to zero: two, four, five, three, six, eight, nine, one,
# Nearest to with: the, a, to, in, of, which, and, by,
# Nearest to that: not, be, to, there, as, however, a, have,
# Nearest to by: the, of, in, a, and, to, as, s,
# Nearest to may: or, that, not, as, however, have, be, to,
# Nearest to or: be, have, some, are, may, there, that, it,
# Nearest to first: in, of, by, the, to, second, at, one,
# Nearest to pre: from, the, its, of, and, other, existing, to,
# Nearest to something: know, you, else, bad, thing, be, anything, think,
# Nearest to versions: version, windows, operating, unix, software, developers, compatible, compatibility,
# Nearest to issue: legal, act, political, opposition, interests, enforce, decision, decisions,
# Nearest to writers: novelists, poets, fiction, literature, authors, biographical, biography, published,
# Nearest to operations: operation, force, support, command, for, advantage, operator, improved,
# Nearest to experience: thinking, mind, thought, human, reason, our, conscious, psychological,
# Nearest to active: activity, ongoing, countries, nations, and, states, commerce, encouraging,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 5.0325 0.0301 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 5.1034 0.0290 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 5.0321 0.0290 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.9274 0.0289 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 5.0192 0.0288 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 5.0873 0.0289 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.9801 0.0288 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.7745 0.0289 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.9341 0.0288 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.9428 0.0289 sec/batch
# Nearest to but: to, the, while, as, only, in, from, have,
# Nearest to zero: two, five, four, seven, one, three, six, eight,
# Nearest to with: to, and, a, the, also, as, in, are,
# Nearest to that: be, not, the, this, any, to, is, it,
# Nearest to by: the, of, in, from, which, to, a, and,
# Nearest to may: or, be, not, is, that, can, this, to,
# Nearest to or: are, is, be, some, these, such, to, other,
# Nearest to first: the, second, at, of, was, last, on, to,
# Nearest to pre: throughout, of, historical, also, modern, earliest, today, many,
# Nearest to something: say, bad, anything, want, not, you, might, know,
# Nearest to versions: version, operating, computers, release, computer, graphics, pc, newer,
# Nearest to issue: rights, independent, the, controversy, legal, political, debate, terms,
# Nearest to writers: novelists, literature, poets, fiction, literary, author, works, essay,
# Nearest to operations: operation, operator, operate, u, improved, support, force, closed,
# Nearest to experience: mind, thinking, perception, do, thought, how, rather, others,
# Nearest to active: especially, between, the, other, on, important, currently, commerce,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 5.0474 0.0300 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.9827 0.0289 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.9016 0.0290 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.9542 0.0289 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 5.0274 0.0289 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 5.0444 0.0290 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.8469 0.0290 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.8893 0.0288 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.9709 0.0289 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.9395 0.0288 sec/batch
# Nearest to but: to, their, that, the, they, not, have, it,
# Nearest to zero: two, five, three, one, seven, eight, four, six,
# Nearest to with: to, a, the, and, by, an, on, more,
# Nearest to that: not, be, to, this, it, is, if, an,
# Nearest to by: of, the, a, for, to, and, in, an,
# Nearest to may: to, or, be, a, is, some, have, an,
# Nearest to or: are, to, be, is, have, an, usually, as,
# Nearest to first: was, s, later, a, on, and, the, in,
# Nearest to pre: the, its, several, were, of, ancient, to, other,
# Nearest to something: things, say, not, know, you, that, knowing, does,
# Nearest to versions: version, format, pc, compatible, read, standard, original, editors,
# Nearest to issue: issues, rights, been, justice, society, public, decision, controversy,
# Nearest to writers: fiction, literature, novelists, literary, authors, bibliography, wrote, novel,
# Nearest to operations: operation, implementing, security, support, force, provides, tasks, joint,
# Nearest to experience: thinking, because, feeling, focus, not, what, do, yet,
# Nearest to active: such, other, and, for, activity, include, major, which,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.9645 0.0302 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 5.0321 0.0288 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.8301 0.0289 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.9453 0.0289 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 5.0075 0.0288 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.8487 0.0289 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.8856 0.0288 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.9140 0.0290 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.8546 0.0289 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.7716 0.0288 sec/batch
# Nearest to but: to, it, that, a, being, be, the, this,
# Nearest to zero: two, five, three, six, one, eight, four, nine,
# Nearest to with: in, the, a, to, of, as, which, and,
# Nearest to that: this, not, a, to, the, they, be, is,
# Nearest to by: the, of, and, in, a, to, this, as,
# Nearest to may: or, this, not, these, that, to, certain, be,
# Nearest to or: are, such, is, be, a, to, not, may,
# Nearest to first: s, time, on, at, and, a, new, for,
# Nearest to pre: of, the, were, in, was, as, with, into,
# Nearest to something: you, know, things, else, think, nothing, do, person,
# Nearest to versions: version, text, graphics, computer, windows, computers, compatible, using,
# Nearest to issue: within, policy, debate, rights, which, dealing, without, decision,
# Nearest to writers: novelists, authors, literary, novels, fiction, stories, science, author,
# Nearest to operations: operation, u, on, security, support, joint, command, force,
# Nearest to experience: thinking, focus, individual, things, reason, objective, mind, that,
# Nearest to active: which, and, process, of, activity, such, binding, are,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.8502 0.0301 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.9090 0.0290 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.9243 0.0290 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.9987 0.0290 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 5.1115 0.0289 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.7703 0.0288 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.9416 0.0289 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.8627 0.0289 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.7025 0.0290 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.8815 0.0288 sec/batch
# Nearest to but: to, the, not, it, more, as, only, a,
# Nearest to zero: two, three, four, six, five, nine, seven, one,
# Nearest to with: the, in, a, and, to, time, from, it,
# Nearest to that: to, this, be, not, a, so, the, which,
# Nearest to by: and, the, of, in, a, its, from, also,
# Nearest to may: to, that, not, be, have, the, as, cases,
# Nearest to or: some, be, different, as, this, which, it, a,
# Nearest to first: in, the, at, after, and, s, was, a,
# Nearest to pre: of, also, as, today, ages, with, other, in,
# Nearest to something: you, know, tell, anything, what, nothing, say, does,
# Nearest to versions: version, windows, latest, pc, software, graphics, users, graphical,
# Nearest to issue: political, rights, democracy, government, accept, membership, independent, nations,
# Nearest to writers: novelists, authors, fiction, biography, literature, books, literary, bibliography,
# Nearest to operations: operation, security, command, base, operational, attack, force, navy,
# Nearest to experience: mind, thinking, feeling, what, whether, individual, perception, self,
# Nearest to active: the, and, which, has, demands, to, in, are,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.8746 0.0301 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.8769 0.0290 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
